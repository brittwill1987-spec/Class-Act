# %% [markdown]
# <a href="https://colab.research.google.com/github/brittwill1987-spec/Class-Act/blob/main/AIML_2013_week1_setup.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello, Computer Vision!")
# Out:
# Hello, Computer Vision!

# %%
# !pip install google-genai
